# %% [markdown]
# <a href="https://colab.research.google.com/github/gremlin97/Misc/blob/main/RemoteSensingTorchGeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pretrained Weights
#
# In this tutorial, we demonstrate some available pretrained weights in TorchGeo. The implementation follows torchvisions' recently introduced [Multi-Weight API](https://pytorch.org/blog/introducing-torchvision-new-multi-weight-support-api/). We will use the [EuroSAT](https://torchgeo.readthedocs.io/en/stable/api/datasets.html#eurosat) dataset throughout this tutorial. Specifically, a subset containing only 100 images.
#
# It's recommended to run this notebook on Google Colab if you don't have your own GPU. Click the "Open in Colab" button above to get started.

# %% [markdown]
# ## Setup
#
# First, we install TorchGeo.

# %%
# %pip install torchgeo
# %pip install timm==0.9.12 # Added timm dependency (v0.9.12)
# Out:
# Requirement already satisfied: torchgeo in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.7.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.9.5)
# Requirement already satisfied: kornia>=0.6.9 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.7.1)
# Requirement already satisfied: lightly>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.4.26)
# Requirement already satisfied: lightning[pytorch-extra]>=2 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.1.4)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (3.7.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.23.5)
# Requirement already satisfied: pandas>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.5.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (9.4.0)
# Requirement already satisfied: pyproj>=3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (3.6.1)
# Requirement already satisfied: rasterio>=1.2 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.3.9)
# Requirement already satisfied: rtree>=1 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.2.0)
# Requirement already satisfied: segmentation-models-pytorch>=0.2 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.3.3)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.0.2)
# Requirement already satisfied: timm>=0.4.12 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.9.2)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.1.0+cu121)
# Requirement already satisfied: torchmetrics>=0.10 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.3.0.post0)
# Requirement already satisfied: torchvision>=0.13 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.16.0+cu121)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (2023.11.17)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->torchgeo) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia>=0.6.9->torchgeo) (23.2)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (1.3.2)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (0.0.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (2.31.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (4.66.1)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (2.0.7)
# Requirement already satisfied: pydantic<2,>=1.10.5 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (1.10.14)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (3.1.15)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from lightly>=1.4.4->torchgeo) (2.1.4)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (6.0.1)
# Requirement already satisfied: fsspec[http]<2025.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (2023.6.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (0.10.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (4.5.0)
# Requirement already satisfied: bitsandbytes<1.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (0.42.0)
# Requirement already satisfied: jsonargparse[signatures]<5.0,>=4.26.1 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (4.27.4)
# Requirement already satisfied: omegaconf<3.0,>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (2.3.0)
# Requirement already satisfied: rich<14.0,>=12.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (13.7.0)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]>=2->torchgeo) (2.6.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->torchgeo) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->torchgeo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->torchgeo) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->torchgeo) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->torchgeo) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.3->torchgeo) (2023.4)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->torchgeo) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->torchgeo) (1.4.7)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.4)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm>=0.4.12->torchgeo) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.4.12->torchgeo) (0.4.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch>=0.2->torchgeo) (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->torchgeo) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->torchgeo) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->torchgeo) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->torchgeo) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->torchgeo) (2.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes<1.0->lightning[pytorch-extra]>=2->torchgeo) (1.11.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (3.9.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.0.0->lightly>=1.4.4->torchgeo) (4.9.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]<5.0,>=4.26.1->lightning[pytorch-extra]>=2->torchgeo) (0.15)
# Requirement already satisfied: typeshed-client>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]<5.0,>=4.26.1->lightning[pytorch-extra]>=2->torchgeo) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly>=1.4.4->torchgeo) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly>=1.4.4->torchgeo) (3.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]>=2->torchgeo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]>=2->torchgeo) (2.16.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX<3.0,>=2.2->lightning[pytorch-extra]>=2->torchgeo) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->torchgeo) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12->torchgeo) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning[pytorch-extra]>=2->torchgeo) (4.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning[pytorch-extra]>=2->torchgeo) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]<5.0,>=4.26.1->lightning[pytorch-extra]>=2->torchgeo) (6.1.1)
# Collecting timm==0.9.12
#   Using cached timm-0.9.12-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm==0.9.12) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.9.12) (0.16.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.12) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.9.12) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.12) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.12) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.12) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.12) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.12) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.9.12) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.9.12) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm==0.9.12) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.12) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.12) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.12) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm==0.9.12) (1.3.0)
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 0.9.2
#     Uninstalling timm-0.9.2:
#       Successfully uninstalled timm-0.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segmentation-models-pytorch 0.3.3 requires timm==0.9.2, but you have timm 0.9.12 which is incompatible.
# Successfully installed timm-0.9.12

# %% [markdown]
# ## Imports
#
# Next, we import TorchGeo and any other libraries we need.

# %%
# %matplotlib inline

import os
import tempfile

import timm
import torch
from lightning.pytorch import Trainer

from torchgeo.datamodules import EuroSAT100DataModule
from torchgeo.trainers import ClassificationTask
from torchgeo.models import ResNet18_Weights

# %% [markdown]
# The following variables can be used to control training.

# %%
batch_size = 16
num_workers = 2
max_epochs = 10
fast_dev_run = False

# %% [markdown]
# ## Datamodule
#
# We will utilize TorchGeo's [Lightning](https://lightning.ai/docs/pytorch/stable/) datamodules to organize the dataloader setup.

# %%
root = os.path.join(tempfile.gettempdir(), "eurosat100")
datamodule = EuroSAT100DataModule(
    root=root, batch_size=batch_size, num_workers=num_workers, download=True
)

# %% [markdown]
# ## Weights
#
# Available pretrained weights are listed on the model documentation [page](https://torchgeo.readthedocs.io/en/stable/api/models.html). While some weights only accept RGB channel input, some weights have been pretrained on Sentinel 2 imagery with 13 input channels and can hence prove useful for transfer learning tasks involving Sentinel 2 data.
#
# To access these weights you can do the following:

# %%
weights = ResNet18_Weights.SENTINEL2_ALL_MOCO

# %% [markdown]
# This set of weights is a torchvision `WeightEnum` and holds information such as the download url link or additional meta data. TorchGeo takes care of the downloading and initialization of models with a desired set of weights. Given that EuroSAT is a classification dataset, we can use a `ClassificationTask` object that holds the model and optimizer object as well as the training logic.

# %%
task = ClassificationTask(
    model="resnet18",
    loss="ce",
    weights=weights,
    in_channels=13,
    num_classes=10,
    lr=0.001,
    patience=5,
)

# %% [markdown]
# If you do not want to utilize the `ClassificationTask` functionality for your experiments, you can also just create a [timm](https://github.com/rwightman/pytorch-image-models) model with pretrained weights from TorchGeo as follows:

# %%
in_chans = weights.meta["in_chans"]
model = timm.create_model("resnet18", in_chans=in_chans, num_classes=10)
model = model.load_state_dict(weights.get_state_dict(progress=True), strict=False)

# %% [markdown]
# ## Training
#
# To train our pretrained model on the EuroSAT dataset we will make use of Lightning's [Trainer](https://lightning.ai/docs/pytorch/stable/common/trainer.html). For a more elaborate explanation of how TorchGeo uses Lightning, check out [this tutorial](https://torchgeo.readthedocs.io/en/stable/tutorials/trainers.html).

# %%
accelerator = "gpu" if torch.cuda.is_available() else "cpu"
default_root_dir = os.path.join(tempfile.gettempdir(), "experiments")

# %%
trainer = Trainer(
    accelerator=accelerator,
    default_root_dir=default_root_dir,
    fast_dev_run=fast_dev_run,
    log_every_n_steps=1,
    min_epochs=1,
    max_epochs=max_epochs,
)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
trainer.fit(model=task, datamodule=datamodule)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 11.2 M
# ---------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.852    Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 11.2 M
# ---------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.852    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.

# %%
# Test the model
trainer.test(model=task, datamodule=datamodule)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   test_AverageAccuracy    │            0.5            │
# │       test_F1Score        │            0.5            │
# │     test_JaccardIndex     │    0.38928571343421936    │
# │   test_OverallAccuracy    │            0.5            │
# │         test_loss         │    1.3704547882080078     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 1.3704547882080078,
#   'test_AverageAccuracy': 0.5,
#   'test_F1Score': 0.5,
#   'test_JaccardIndex': 0.38928571343421936,
#   'test_OverallAccuracy': 0.5}]

# %% [markdown]
# ## Using Resnet50 Weights from Landsat 7
# ***Weights:*** ResNet50_Weights.LANDSAT_ETM_SR_MOCO
#
# ---

# %%
# Import Resnet50 weights
from torchgeo.models import ResNet50_Weights
weights_landsat7 = ResNet50_Weights.LANDSAT_ETM_SR_MOCO

# %%
# Setup classification task
task_resnet50_ls7 = ClassificationTask(
    model="resnet50",
    loss="ce",
    weights=weights_landsat7,
    in_channels=13,
    num_classes=10,
    lr=0.001,
    patience=5,
)

# %%
# Creating trainer
accelerator = "gpu" if torch.cuda.is_available() else "cpu"
default_root_dir = os.path.join(tempfile.gettempdir(), "experiments_rs50")

trainerr50 = Trainer(
    accelerator=accelerator,
    default_root_dir=default_root_dir,
    fast_dev_run=fast_dev_run,
    log_every_n_steps=1,
    min_epochs=1,
    max_epochs=max_epochs,
)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
# Train the model on the EuroSat100 dataset
trainerr50.fit(model=task_resnet50_ls7, datamodule=datamodule)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory /tmp/experiments_rs50/lightning_logs/version_0/checkpoints exists and is not empty.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 23.6 M
# ---------------------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.240    Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 23.6 M
# ---------------------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.240    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.

# %%
trainerr50.test(model=task_resnet50_ls7, datamodule=datamodule)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   test_AverageAccuracy    │    0.5500000715255737     │
# │       test_F1Score        │     0.550000011920929     │
# │     test_JaccardIndex     │    0.46166667342185974    │
# │   test_OverallAccuracy    │     0.550000011920929     │
# │         test_loss         │    1.9564851522445679     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 1.9564851522445679,
#   'test_AverageAccuracy': 0.5500000715255737,
#   'test_F1Score': 0.550000011920929,
#   'test_JaccardIndex': 0.46166667342185974,
#   'test_OverallAccuracy': 0.550000011920929}]

# %% [markdown]
# ## Using a different dataset
# ***Dataset used:*** UC Merced Dataset

# %%
# Loading Data Module
from torchgeo.datamodules import UCMercedDataModule
datamodule_ucm = UCMercedDataModule(batch_size=batch_size, num_workers=num_workers, download=True)

# %%
# Creating classification task for Sentinel2 - Resnet18
tasks2_r18 = ClassificationTask(
    model="resnet18",
    loss="ce",
    weights=weights,
    in_channels=3,
    num_classes=21,
    lr=0.001,
    patience=5,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchgeo/trainers/utils.py:102: UserWarning: input channels 3 != input channels in pretrained model 13. Overriding with new input channels
#   warnings.warn(

# %%
# Creating trainer
accelerator = "gpu" if torch.cuda.is_available() else "cpu"
default_root_dir = os.path.join(tempfile.gettempdir(), "experiments")

trainerucms2 = Trainer(
    accelerator=accelerator,
    default_root_dir=default_root_dir,
    fast_dev_run=fast_dev_run,
    log_every_n_steps=1,
    min_epochs=1,
    max_epochs=max_epochs,
)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
#==========Training UCM with => Sentinel2 - Resnet18=========#
trainerucms2.fit(model=tasks2_r18, datamodule=datamodule_ucm)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 11.2 M
# ---------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.749    Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 11.2 M
# ---------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.749    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.

# %%
#==========Testing Dataset=========#
trainerucms2.test(model=tasks2_r18, datamodule=datamodule_ucm)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   test_AverageAccuracy    │     0.722862720489502     │
# │       test_F1Score        │    0.7285714149475098     │
# │     test_JaccardIndex     │    0.6057404279708862     │
# │   test_OverallAccuracy    │    0.7285714149475098     │
# │         test_loss         │    1.0774142742156982     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 1.0774142742156982,
#   'test_AverageAccuracy': 0.722862720489502,
#   'test_F1Score': 0.7285714149475098,
#   'test_JaccardIndex': 0.6057404279708862,
#   'test_OverallAccuracy': 0.7285714149475098}]

# %%
# Creating classification task for Sentinel2 - Resnet18
task2_r50_ls7 = ClassificationTask(
    model="resnet50",
    loss="ce",
    weights=weights_landsat7,
    in_channels=3,
    num_classes=21,
    lr=0.001,
    patience=5,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchgeo/trainers/utils.py:102: UserWarning: input channels 3 != input channels in pretrained model 6. Overriding with new input channels
#   warnings.warn(

# %%
# Creating trainer
accelerator = "gpu" if torch.cuda.is_available() else "cpu"
default_root_dir = os.path.join(tempfile.gettempdir(), "experiments")

trainerl7ucm = Trainer(
    accelerator=accelerator,
    default_root_dir=default_root_dir,
    fast_dev_run=fast_dev_run,
    log_every_n_steps=1,
    min_epochs=1,
    max_epochs=max_epochs,
)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
#==========Training UCM with => Landsat7 - Resnet50=========#
trainerl7ucm.fit(model=task2_r50_ls7, datamodule=datamodule_ucm)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 23.6 M
# ---------------------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.204    Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | CrossEntropyLoss | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | test_metrics  | MetricCollection | 0
# 4 | model         | ResNet           | 23.6 M
# ---------------------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.204    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.

# %%
trainerl7ucm.test(model=task2_r50_ls7, datamodule=datamodule_ucm)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   test_AverageAccuracy    │    0.8255534172058105     │
# │       test_F1Score        │    0.8261904716491699     │
# │     test_JaccardIndex     │     0.714323103427887     │
# │   test_OverallAccuracy    │    0.8261904716491699     │
# │         test_loss         │    0.5683012008666992     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.5683012008666992,
#   'test_AverageAccuracy': 0.8255534172058105,
#   'test_F1Score': 0.8261904716491699,
#   'test_JaccardIndex': 0.714323103427887,
#   'test_OverallAccuracy': 0.8261904716491699}]
